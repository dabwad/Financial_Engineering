# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = 'AAPL'
start_date='2015-04-01'
df=yf.download(ticker, start=start_date)

print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-04-01  27.748461  27.942756  27.491634  27.875757  162485600
# 2015-04-02  27.987423  28.041021  27.735063  27.922658  128880400
# 2015-04-06  28.440777  28.476510  27.766328  27.797594  148776000
# 2015-04-07  28.141525  28.612745  28.134826  28.505549  140049200
# 2015-04-08  28.049948  28.228611  27.909252  28.105780  149316800

# %% [markdown]
# ## Event-Driven Backtest

# %%
short_window = 5 # 단기
long_window = 50 # 장기
data = df.copy()

#지수가중이동평균선 계산
data['Short_MA'] = data[('Close', ticker)].ewm(span=short_window, adjust=False).mean() 
data['Long_MA'] = data[('Close', ticker)].ewm(span=long_window, adjust=False).mean()
data=data[long_window:].copy() #초기데이터 제거

cash_init = 1000000
cash = cash_init
asset=[cash]
pos = 0

for i in range(1, len(data)):
    if pos == 0:
        if data['Short_MA'].iloc[i] > data['Long_MA'].iloc[i] and \
        data['Short_MA'].iloc[i-1] < data['Long_MA'].iloc[i-1]:
            pos = 1
            entry_price=data[('Close', ticker)].iloc[i]
            num=int(cash/entry_price)
            cash-=entry_price*num
    elif pos==1:
        if data['Short_MA'].iloc[i] < data['Long_MA'].iloc[i] and \
        data['Short_MA'].iloc[i-1] > data['Long_MA'].iloc[i-1]:
            pos = 0
            entry_price=data[('Close', ticker)].iloc[i]
            cash+=entry_price*num

    # 자산 가치 갱신 기록
    if pos == 0:
        asset.append(cash)
    elif pos == 1:
        asset.append(cash+data[('Close', ticker)].iloc[i]*num)

# 누적 수익률 계산 출력
data['Cumulative_Return']=np.array(asset)/cash_init
final_cum_return=data['Cumulative_Return'].iloc[-1]-1
print(f'Final cumulative return of the strategy: {100*final_cum_return: .2f}%')
# Out:
# Final cumulative return of the strategy:  397.91%

# %% [markdown]
# ## Signal-based 속도 개선 version

# %%
short_window = 5 # 단기
long_window = 20 # 장기
data = df.copy()

#지수가중이동평균선 계산
data['Short_MA'] = data[('Close', ticker)].ewm(span=short_window, adjust=False).mean()
data['Long_MA'] = data[('Close', ticker)].ewm(span=long_window, adjust=False).mean()
data=data[long_window:].copy() #초기데이터 제거


#포지션과 시그널 계산
data['Position']=np.where(data['Short_MA']>data['Long_MA'], 1, 0)
data['Signal']=data['Position'].diff().fillna(0) #1: 매수, -1: 매도

prices=data[('Close', ticker)].values
signals=data['Signal'].values

cash_init = 1000000
cash = cash_init
asset=np.zeros(len(data))
asset[0]=cash
pos = 0

for i in range(1, len(data)):
    if pos == 0:
        if signals[i]==1:
            pos = 1
            entry_price=prices[i]
            num=int(cash/entry_price)
            cash-=entry_price*num
    elif pos==1:
        if signals[i]==-1:
            pos = 0
            entry_price=prices[i]
            cash+=entry_price*num

    # 자산 가치 갱신 기록
    if pos == 0:
        asset[i]=cash
    elif pos == 1:
        asset[i]=cash+prices[i]*num

# 누적 수익률 계산 출력
data['Cumulative_Return']=np.array(asset)/cash_init
final_cum_return=data['Cumulative_Return'].iloc[-1]-1
print(f'Final cumulative return of the strategy: {100*final_cum_return: .2f}%')

#시각화를 위한 매수, 매도 시점의 가격 칼럼 계산
data['Buy_Price'] = np.where(signals==1, prices, np.nan)
data['Sell_Price'] = np.where(signals==-1, prices, np.nan)
# Out:
# Final cumulative return of the strategy:  765.95%

# %% [markdown]
# ## 시각화

# %%
fig, ax = plt.subplots(2, 1, sharex=True, height_ratios=(8, 2), figsize=(10,8))

data['Close'].plot(ax=ax[0], label='Close')
data['Short_MA'].plot(ax=ax[0], label='Short MA', linewidth=1)
data['Long_MA'].plot(ax=ax[0], label='Long MA', linewidth=1)
data['Buy_Price'].plot(ax=ax[0], label='Buy', marker='^', color='b', markersize=8)
data['Sell_Price'].plot(ax=ax[0], label='Sell', marker='v', color='r', markersize=8)

ax[0].set_title(f'{ticker} Moving Average Crossover Trades Strategy (Short: {a}, Long: {b})', fontsize=18)
ax[0].set_ylabel('Price($)', fontsize=12)
ax[0].legend(fontsize=12)
ax[0].grid(alpha=0.3)

data['Position'].plot(ax=ax[1])
ax[1].set_xlabel('Date', fontsize=12)
ax[1].set_ylabel('Position', fontsize=12)
ax[0].grid(alpha=0.3)

plt.xticks(rotation=0)
plt.tight_layout()

plt.savefig('chart.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\marigold\Financial_Engineering\미국주식퀀트투자
# ['.ipynb_checkpoints', 'chart.png', '추세추종전략_백테스트.ipynb']

# %% [markdown]
# ## Vectorized Backtest

# %%
def mac_strategy1(df, sw, lw): 
    short_window = sw # 단기
    long_window = lw # 장기
    data = df.copy()
    
    #지수가중이동평균선 계산
    data['Short_MA'] = data[('Close', ticker)].ewm(span=short_window, adjust=False).mean() # shor_window 기간 동안의 지수가중평균 가격 데이터프레임
    data['Long_MA'] = data[('Close', ticker)].ewm(span=long_window, adjust=False).mean()
    data=data[long_window:].copy() #초기데이터 제거
    
    #포지션 및 시그널 계산
    
    # 계산용 시리즈 생성
    positions = pd.Series(np.where(data['Short_MA']>data['Long_MA'], 1, 0), index=data.index)
    signals = positions.diff().fillna(0)
    
    #데이터프레임에 실제 전략 결과 반영
    data['Position']=np.nan #포지션 초기화
    data.loc[signals==1, 'Position']=1 #매수 시점 포지션
    data.loc[signals==-1, 'Position']=0 #매도 시점 포지션
    data['Position']=data['Position'].ffill() #이전 포지션(위의 값)을 그대로 유지
    data['Position']=data['Position'].replace(np.nan, 0) #결측값 처리
    
    data['Signal']=data['Position'].diff().fillna(0) #최종 시그널 계산
    
    #매수, 매도 시점의 가격 기록
    data['Buy_Price'] = np.where(data['Signal'] == 1, data[('Close', ticker)], np.nan)
    data['Sell_Price'] = np.where(data['Signal'] == -1, data[('Close', ticker)], np.nan)
    
    #일별 수익률 및 누적 수익률 계산
    data['Daily_Return'] = np.where(data['Position'].shift()==1, data[('Close', ticker)].pct_change(),0) #어제 주식을 들고 있었으면 어제 대비 수익률 반영
    data['Cumulative_Return']=(1+data['Daily_Return']).cumprod() #매일 종가 수익률 기반 누적 수익률 (복리 계산)
    
    #최종 누적 수익률 출력
    final_cum_return=data['Cumulative_Return'].iloc[-1]-1
    print(f'Final cumulative return of the strategy: {100*final_cum_return: .2f}%')

    return data, final_cum_return

# %% [markdown]
# ## 파라미터 최적화

# %%
def parameter_optimizer1(input_df):
    #장단기 설정
    short_window = list(range(5, 22))  # 5~21
    long_window = list(range(22, 51))  # 22~50
    ret_list=[] #각 파라미터 조합과 수익률을 저장할 리스트

    #장단기 모든 조합에 대해 테스트
    for x1, x2 in [(a,b) for a in short_window for b in long_window]:
        df = input_df.copy()
        _, ret = mac_strategy1(df, x1, x2)
        ret_list.append((x1, x2, ret))

    #수익률이 최대인 파라미터 조합을 찾아 출력하고 결과를 반환
    optimal_params = max(ret_list, key=lambda x:x[2]) # 리스트 내의 튜플의 ret값을 기준으로 max 튜플 찾기
    optimal_df = pd.DataFrame(ret_list, columns=['short_window', 'long_window', 'ror'])  #리스트를 데이터프레임화
    return optimal_params, optimal_df

# %% [markdown]
# ## 파라미터 최적화 업그레이드

# %%
def parameter_optimizer2(input_df):
    #장단기 설정
    short_window = list(range(5, 22))  # 5~21
    long_window = list(range(22, 51))  # 22~50
    ret_list=[] #각 파라미터 조합과 수익률을 저장할 리스트

    #장단기 모든 조합에 대해 테스트
    for x1, x2 in [(a,b) for a in short_window for b in long_window]:
        df = input_df.copy()
        _, ret = mac_strategy1(df, x1, x2)
        ret_list.append((x1, x2, ret))


    # 여러 개의 최적해를 '모두' 찾고 최적값은 중위값을 선택
    max_ror = max(ret_list, key=lambda x:x[2])[2]  # ret 값 기준으로 최대인 튜플 찾고, 거기서 ret값만 저장
    max_tups=[tup for tup in ret_list if tup[2] == max_ror] # 맥스 ret값을 만족하는 모든 tup 찾아서 리스트에 저장
    params1=[tup[0] for tup in max_tups] 
    params2=[tup[1] for tup in max_tups]
    opt_param1 = int(np.median(params1))
    opt_param2 = int(np.median(params2))
    
    optimal_df = pd.DataFrame(max_tups, columns=['short_window', 'long_window', 'ror'])  #리스트를 데이터프레임화

    print(f'Max Tuples: {max_tups}')
    print(f'Optimal Parameters:{opt_param1, opt_param2}, ' f'Optimized Return:{100*max_ror: .2f}%')
    
    return (opt_param1, opt_param2), optimal_df # return optimal_params, optimal_df랑 동일

# %%
o_p, o_d = parameter_optimizer2(df)
print(f'Optimal parameters:{o_p[0], o_p[1]}, ' f'Optimized Return:{100*o_d["ror"].iloc[0]:.2f}%')
# Out:
# Final cumulative return of the strategy:  740.04%
# Final cumulative return of the strategy:  757.87%
# Final cumulative return of the strategy:  734.42%
# Final cumulative return of the strategy:  697.88%
# Final cumulative return of the strategy:  696.17%
# Final cumulative return of the strategy:  647.53%
# Final cumulative return of the strategy:  618.02%
# Final cumulative return of the strategy:  543.81%
# Final cumulative return of the strategy:  426.34%
# Final cumulative return of the strategy:  424.42%
# Final cumulative return of the strategy:  409.60%
# Final cumulative return of the strategy:  413.01%
# Final cumulative return of the strategy:  384.28%
# Final cumulative return of the strategy:  421.75%
# Final cumulative return of the strategy:  267.14%
# Final cumulative return of the strategy:  266.08%
# Final cumulative return of the strategy:  298.45%
# Final cumulative return of the strategy:  300.16%
# Final cumulative return of the strategy:  307.89%
# Final cumulative return of the strategy:  337.88%
# Final cumulative return of the strategy:  305.78%
# Final cumulative return of the strategy:  305.84%
# Final cumulative return of the strategy:  314.28%
# Final cumulative return of the strategy:  277.96%
# Final cumulative return of the strategy:  268.98%
# Final cumulative return of the strategy:  334.52%
# Final cumulative return of the strategy:  317.05%
# Final cumulative return of the strategy:  291.22%
# Final cumulative return of the strategy:  253.42%
# Final cumulative return of the strategy:  267.12%
# Final cumulative return of the strategy:  297.69%
# Final cumulative return of the strategy:  290.55%
# Final cumulative return of the strategy:  279.45%
# Final cumulative return of the strategy:  261.54%
# Final cumulative return of the strategy:  261.73%
# Final cumulative return of the strategy:  226.76%
# Final cumulative return of the strategy:  234.48%
# Final cumulative return of the strategy:  222.87%
# Final cumulative return of the strategy:  236.82%
# Final cumulative return of the strategy:  219.77%
# Final cumulative return of the strategy:  195.59%
# Max Tuples: [(5, 23, np.float64(7.578745284882006))]
# Optimal Parameters:(5, 23), Optimized Return: 757.87%
# Optimal parameters:(5, 23), Optimized Return:757.87%

# %%
data, _ = mac_strategy1(df, a, b)
# Out:
# Final cumulative return of the strategy:  757.87%

# %% [markdown]
#  ## 성능 지표 tear sheet 제작

# %%
def tear_sheet1(data):

    # 투자기간 
    trading_period = len(data)/252
    print(f'Trading Period: {trading_period:.1f} years')

    # 누적 수익률
    buy_and_hold = data[('Close', ticker)].iloc[-1]/data[('Close', ticker)].iloc[0] - 1 # 그냥 사서 들고 있었을 때의 누적 수익률
    final_cum_return = data['Cumulative_Return'].iloc[-1] - 1 # 추세추종전략 시행시의 누적 수익률
    print(f'Final cumulative return of the strategy: {100*final_cum_return:.2f}%, Buy&Hold:{100*buy_and_hold:.2f}%')

    # 연평균 수익률 CAGR
    CAGR_benchmark = (buy_and_hold+1)**(1/trading_period)-1
    CAGR_strategy = (data['Cumulative_Return'].iloc[-1])**(1/trading_period)-1 
    # data['Cumulative_Return']이 자주 나오는데, 
    # 만약 데이터가 매우 크고 반복 계산이 많다면 CR=data[...].values로 따로 뽑아서 numpy 배열로 작업하는 게 훨씬 빠르긴 함
    # 아니면 편의상 CR = data['Cumulative_Return']로 놓고 쓸 수도 있고 뭐
    print(f'Strategy CAGR: {100*CAGR_strategy: .2f}%, Benchmark CAGR: {100*CAGR_benchmark:.2f}%')

    # 샤프지수
    risk_free_rate = 0.003
    strategy_daily_return = data['Cumulative_Return'].pct_change().fillna(0) # 일일 수익률 싹 다 계산
    mean_return = strategy_daily_return.mean()*252 # 일일 수익률 평균에 252를 곱해서 연 평균 수익률로 다시 환산
    std_return=strategy_daily_return.std()*np.sqrt(252) # 동일
    sharp_ratio=(mean_return - risk_free_rate) / std_return
    print(f'Sharpe Ratio: {sharp_ratio:.2f}')

    # 최대 낙폭 MDD(Maximum DrawDown)

    # 전략의 MDD
    data['Cumulative_Max']=data['Cumulative_Return'].cummax() # 누적 수익률의 최고값을 계속 추적해서 끌고 감. [1.2, 0.9, 1.3, 0.8] >> [1.2, 1.2, 1.3, 1.3]
    data['Drawdown'] = data['Cumulative_Return'] / data ['Cumulative_Max'] - 1 # 최고 수익률 대비 현재 수익률 (낙폭)
    max_drawdown = data['Drawdown'].min() # 낙폭 중 가장 깊은 순간 캐치

    # 벤치마크 MDD
    cumulative_returns = (1 + data[('Close', ticker)].pct_change()).cumprod() # 하루하루 주가 변화량을 적어놓고, 거기에 1을 더한 상태에서, 앞에서부터 복리로 누적곱 계산)
    running_max = cumulative_returns.cummax()
    drawdown = cumulative_returns/running_max - 1 # 당시 주가가 최고점 대비 얼마나 하락했는지 (현재 수익률 / 최고 수익률 - 1)
    mdd_benchmark = drawdown.min() # 낙폭 중 가장 깊은 순간 캐치

    print(f'Strategy MDD: {100*max_drawdown:.2f}%, Benchmark MDD: {100*mdd_benchmark:.2f}%')

    # 승률
    buy_signals = data[data['Signal'] == 1].index #매수 '날짜' 추출한 리스트
    sell_signals = data[data['Signal'] == -1].index #매도 '날짜' 추출한 리스트
    
    returns = []
    holding_periods = []
    
    for buy_date in buy_signals:
        sell_dates = sell_signals[sell_signals > buy_date] # pandas 인덱스 슬라이싱. 매수 날짜보다 나중에 오는 매도 날짜 리스트
        if not sell_dates.empty: # 매수 이후에 매도가 있으면 실행
            sell_date = sell_dates[0] # 매수 이후 첫 번째 매도 날짜
            buy_price = data.loc[buy_date, ('Close', ticker)] # 매수 때의 종가
            sell_price = data.loc[sell_date, ('Close', ticker)] #매도 때의 종가
            return_pct = sell_price/buy_price - 1 # 수익률
            returns.append(return_pct) # 수익률 리스트에 추가
            holding_period = np.busday_count(buy_date.date(), sell_date.date()) # np.busday_count(start, end)는 영업일 기준 일수 계산. buy_date.date()는 날짜에서  
            holding_periods.append(holding_period) # 보유일 수 (=보유기간) 리스트에 추가
            
    profitable_trades = len([r for r in returns if r > 0]) # 수익 난 거래 일 수 변수에 저장
    loss_trades = len([r for r in returns if r <=0]) # 손실 거래 일 수 
    total_trades = len(returns) # 전체 거래 일 수
    win_rate = profitable_trades / total_trades if total_trades > 0 else 0
    print(f'Number of Profitable Trades:{profitable_trades}, Number of Loss Trades:{loss_trades}, Win Rate:{100*win_rate:.2f}%')

    # 평균 보유 기간
    if holding_periods: # 리스트가 비어 있지 않으면(True이면)
        average_holding_period = np.mean(holding_periods)
    else:
        average_holding_period = 0
    print(f'Average Holding Period:{average_holding_period:.1f}days')

    # 평균 이익과 손실
    if profitable_trades > 0:
        average_profit = np.mean([r for r in returns if r > 0])
    else:
        average_profit = 0
        
    if loss_trades > 0:
        average_loss = np.mean([r for r in returns if r <=0])
    else:
        average_loss = 0
        
    print(f'Avg ROR/trade in profitable trades:{average_profit:.3f}%. Avg ROR/trade in loss trades:{average_loss:.3f}%')

    # 손익비
    if average_loss != 0:
        profit_loss_ratio = average_profit / abs(average_loss)
    else:
        profit_loss_ratio = np.inf # 손실이 하나도 없으면 손익비=무한대로 처리

    print(f'Profit/Loss Ratio: {profit_loss_ratio:.2f}')

# %%
tear_sheet1(data)
# Out:
# Trading Period: 9.9 years
# Final cumulative return of the strategy: 765.95%, Buy&Hold:562.28%
# Strategy CAGR:  24.30%, Benchmark CAGR: 20.98%
# Sharpe Ratio: 1.24
# Strategy MDD: -21.61%, Benchmark MDD: -38.52%
# Number of Profitable Trades:24, Number of Loss Trades:32, Win Rate:42.86%
# Average Holding Period:28.8days
# Avg ROR/trade in profitable trades:0.144%. Avg ROR/trade in loss trades:-0.027%
# Profit/Loss Ratio: 5.31

# %% [markdown]
# ## 추적 손절 Event_Driven

# %%
def mac_strategy2a(df, sw, lw, sl, verbose=True):
    stop_loss = sl
    short_window = sw
    long_window = lw
    data = df.copy()

    #지수가중이동평균선 계산
    data['Short_MA'] = data[('Close', ticker)].ewm(span=short_window, adjust=False).mean()
    data['Long_MA'] = data[('Close', ticker)].ewm(span=long_window, adjust=False).mean()
    data=data[long_window:].copy() #초기데이터 제거


    # 계산용 시리즈 생성 
    # 손절 기능이 있어서 아직 S>L이어도 바로 매도가 나갈 수 있기 때문에,
    # 기존 Event-Driven 방식처럼 바로 데이터프레임에 넣지 않고 우선 Series를 만들어서 따로 계산 후 나중에 데이터프레임에 넣자
    positions = pd.Series(np.where(data['Short_MA']>data['Long_MA'], 1, 0), index=data.index)
    signals = positions.diff().fillna(0)
    
    prices=data[('Close', ticker)].values
    signals=signals.values
    pos_vec = np.zeros(len(data))
    
    cash_init = 1000000
    cash = cash_init
    asset=np.zeros(len(data))
    asset[0]=cash
    pos = 0
    
    for i in range(1, len(data)):
        if pos == 0: # 주식 보유 X
            if signals[i]==1:
                pos_vec[i] = 1
                pos = 1
                entry_price=prices[i]
                num=int(cash/entry_price)
                cash-=entry_price*num
                stop_loss_price = entry_price*(1-stop_loss) # 손절가 설정
                
        elif pos==1: # 주식 보유 O
            if prices[i] < stop_loss_price: # 손절 발생
                pos = 0
                cash +=prices[i]*num
            
            elif signals[i]==-1: # 손절 라인까지 가기 전에 데드크로스 발생
                pos = 0
                cash += prices[i]*num

            else: #포지션 유지 -> 손절가 갱신
                pos_vec[i] = 1
                stop_loss_price = max(stop_loss_price, prices[i]*(1-stop_loss))
    
        # 자산 가치 갱신 기록
        if pos == 0:
            asset[i]=cash
        elif pos == 1:
            asset[i]=cash+prices[i]*num

    data['Position'] = pos_vec
    data['Signal']=data['Position'].diff().fillna(0)
    data['Buy_Price'] = np.where(data['Signal']==1, data[('Close', ticker)], np.nan)
    data['Sell_Price'] = np.where(data['Signal']==-1, data[('Close', ticker)], np.nan)
    
    # 누적 수익률 계산 출력
    data['Cumulative_Return']=np.array(asset)/cash_init
    final_cum_return=data['Cumulative_Return'].iloc[-1]-1

    if verbose: 
        print(f'Final cumulative return of the strategy: {100*final_cum_return: .2f}%')
    
    return data, final_cum_return

# %%
d2, f2 = mac_strategy2a(df, a, b, 0.07, verbose=False)
print(f'Final cumulative return of the strategy: {100*f2: .2f}%')
# Out:
# Final cumulative return of the strategy:  812.95%

# %% [markdown]
# ## TQQQ 벤치마킹 백테스트

# %%
ticker = 'TQQQ'
start_date='2015-04-01'
df=yf.download(ticker, start=start_date)

o_p, o_d = parameter_optimizer2(df)
data, ret = mac_strategy1(df, o_p[0], o_p[1])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Final cumulative return of the strategy:  1494.81%
# Final cumulative return of the strategy:  1154.23%
# Final cumulative return of the strategy:  1530.30%
# Final cumulative return of the strategy:  1673.83%
# Final cumulative return of the strategy:  966.65%
# Final cumulative return of the strategy:  1050.22%
# Final cumulative return of the strategy:  1042.67%
# Final cumulative return of the strategy:  1261.52%
# Final cumulative return of the strategy:  1208.63%
# Final cumulative return of the strategy:  1058.73%
# Final cumulative return of the strategy:  952.34%
# Final cumulative return of the strategy:  883.10%
# Final cumulative return of the strategy:  730.08%
# Final cumulative return of the strategy:  698.25%
# Final cumulative return of the strategy:  697.45%
# Final cumulative return of the strategy:  657.29%
# Final cumulative return of the strategy:  504.20%
# Final cumulative return of the strategy:  392.12%
# Final cumulative return of the strategy:  321.33%
# Final cumulative return of the strategy:  371.28%
# Final cumulative return of the strategy:  411.70%
# Final cumulative return of the strategy:  530.21%
# Final cumulative return of the strategy:  575.68%
# Final cumulative return of the strategy:  648.03%
# Final cumulative return of the strategy:  686.93%
# Final cumulative return of the strategy:  601.31%
# Final cumulative return of the strategy:  581.90%
# Final cumulative return of the strategy:  650.29%
# Final cumulative return of the strategy:  669.75%
# Final cumulative return of the strategy:  1017.99%
# Final cumulative return of the strategy:  1069.85%
# Final cumulative return of the strategy:  1148.15%
# Final cumulative return of the strategy:  1146.86%
# Final cumulative return of the strategy:  1314.85%
# Final cumulative return of the strategy:  1077.76%
# Final cumulative return of the strategy:  930.58%
# Final cumulative return of the strategy:  793.06%
# Final cumulative return of the strategy:  546.99%
# Final cumulative return of the strategy:  565.60%
# Final cumulative return of the strategy:  493.82%
# Final cumulative return of the strategy:  499.68%
# Final cumulative return of the strategy:  501.89%
# Final cumulative return of the strategy:  492.03%
# Final cumulative return of the strategy:  520.25%
# Final cumulative return of the strategy:  508.54%
# Final cumulative return of the strategy:  499.09%
# Final cumulative return of the strategy:  317.58%
# Final cumulative return of the strategy:  459.57%
# Final cumulative return of the strategy:  464.15%
# Final cumulative return of the strategy:  462.39%
# Final cumulative return of the strategy:  599.25%
# Final cumulative return of the strategy:  481.07%
# Final cumulative return of the strategy:  461.18%
# Final cumulative return of the strategy:  431.38%
# Final cumulative return of the strategy:  393.13%
# Final cumulative return of the strategy:  414.53%
# Final cumulative return of the strategy:  406.66%
# Final cumulative return of the strategy:  418.86%
# Final cumulative return of the strategy:  1193.84%
# Final cumulative return of the strategy:  1311.63%
# Final cumulative return of the strategy:  1152.75%
# Final cumulative return of the strategy:  1046.68%
# Final cumulative return of the strategy:  293.29%
# Final cumulative return of the strategy:  348.39%
# Final cumulative return of the strategy:  344.60%
# Final cumulative return of the strategy:  325.22%
# Final cumulative return of the strategy:  319.80%
# Final cumulative return of the strategy:  314.41%
# Final cumulative return of the strategy:  384.19%
# Final cumulative return of the strategy:  377.15%
# Final cumulative return of the strategy:  712.20%
# Final cumulative return of the strategy:  600.63%
# Final cumulative return of the strategy:  618.06%
# Final cumulative return of the strategy:  614.15%
# Final cumulative return of the strategy:  565.21%
# Final cumulative return of the strategy:  496.03%
# Final cumulative return of the strategy:  491.56%
# Final cumulative return of the strategy:  537.49%
# Final cumulative return of the strategy:  574.73%
# Final cumulative return of the strategy:  586.28%
# Final cumulative return of the strategy:  600.57%
# Final cumulative return of the strategy:  460.81%
# Final cumulative return of the strategy:  355.39%
# Final cumulative return of the strategy:  324.61%
# Final cumulative return of the strategy:  362.86%
# Final cumulative return of the strategy:  404.75%
# Final cumulative return of the strategy:  275.74%
# Final cumulative return of the strategy:  254.48%
# Final cumulative return of the strategy:  289.39%
# Final cumulative return of the strategy:  338.09%
# Final cumulative return of the strategy:  318.82%
# Final cumulative return of the strategy:  269.64%
# Final cumulative return of the strategy:  300.34%
# Final cumulative return of the strategy:  357.25%
# Final cumulative return of the strategy:  414.69%
# Final cumulative return of the strategy:  379.83%
# Final cumulative return of the strategy:  340.84%
# Final cumulative return of the strategy:  334.75%
# Final cumulative return of the strategy:  300.39%
# Final cumulative return of the strategy:  620.95%
# Final cumulative return of the strategy:  648.42%
# Final cumulative return of the strategy:  593.89%
# Final cumulative return of the strategy:  446.04%
# Final cumulative return of the strategy:  467.01%
# Final cumulative return of the strategy:  514.60%
# Final cumulative return of the strategy:  564.84%
# Final cumulative return of the strategy:  597.13%
# Final cumulative return of the strategy:  725.33%
# Final cumulative return of the strategy:  515.06%
# Final cumulative return of the strategy:  454.77%
# Final cumulative return of the strategy:  431.32%
# Final cumulative return of the strategy:  392.22%
# Final cumulative return of the strategy:  367.90%
# Final cumulative return of the strategy:  358.26%
# Final cumulative return of the strategy:  338.12%
# Final cumulative return of the strategy:  251.66%
# Final cumulative return of the strategy:  213.40%
# Final cumulative return of the strategy:  251.30%
# Final cumulative return of the strategy:  335.28%
# Final cumulative return of the strategy:  338.96%
# Final cumulative return of the strategy:  243.62%
# Final cumulative return of the strategy:  250.90%
# Final cumulative return of the strategy:  276.04%
# Final cumulative return of the strategy:  296.57%
# Final cumulative return of the strategy:  297.94%
# Final cumulative return of the strategy:  276.62%
# Final cumulative return of the strategy:  254.17%
# Final cumulative return of the strategy:  217.83%
# Final cumulative return of the strategy:  584.46%
# Final cumulative return of the strategy:  498.53%
# Final cumulative return of the strategy:  503.87%
# Final cumulative return of the strategy:  500.37%
# Final cumulative return of the strategy:  617.81%
# Final cumulative return of the strategy:  597.93%
# Final cumulative return of the strategy:  617.05%
# Final cumulative return of the strategy:  525.32%
# Final cumulative return of the strategy:  463.75%
# Final cumulative return of the strategy:  471.68%
# Final cumulative return of the strategy:  339.62%
# Final cumulative return of the strategy:  400.09%
# Final cumulative return of the strategy:  360.59%
# Final cumulative return of the strategy:  351.37%
# Final cumulative return of the strategy:  283.22%
# Final cumulative return of the strategy:  213.22%
# Final cumulative return of the strategy:  237.82%
# Final cumulative return of the strategy:  225.28%
# Final cumulative return of the strategy:  244.94%
# Final cumulative return of the strategy:  244.57%
# Final cumulative return of the strategy:  261.14%
# Final cumulative return of the strategy:  209.88%
# Final cumulative return of the strategy:  288.52%
# Final cumulative return of the strategy:  242.43%
# Final cumulative return of the strategy:  207.23%
# Final cumulative return of the strategy:  177.01%
# Final cumulative return of the strategy:  205.44%
# Final cumulative return of the strategy:  238.78%
# Final cumulative return of the strategy:  256.69%
# Final cumulative return of the strategy:  496.97%
# Final cumulative return of the strategy:  498.57%
# Final cumulative return of the strategy:  604.21%
# Final cumulative return of the strategy:  634.72%
# Final cumulative return of the strategy:  692.03%
# Final cumulative return of the strategy:  578.94%
# Final cumulative return of the strategy:  434.65%
# Final cumulative return of the strategy:  478.21%
# Final cumulative return of the strategy:  410.15%
# Final cumulative return of the strategy:  409.58%
# Final cumulative return of the strategy:  349.39%
# Final cumulative return of the strategy:  327.51%
# Final cumulative return of the strategy:  299.43%
# Final cumulative return of the strategy:  333.67%
# Final cumulative return of the strategy:  223.58%
# Final cumulative return of the strategy:  195.47%
# Final cumulative return of the strategy:  213.32%
# Final cumulative return of the strategy:  197.51%
# Final cumulative return of the strategy:  206.60%
# Final cumulative return of the strategy:  242.61%
# Final cumulative return of the strategy:  219.03%
# Final cumulative return of the strategy:  175.47%
# Final cumulative return of the strategy:  235.92%
# Final cumulative return of the strategy:  185.78%
# Final cumulative return of the strategy:  188.60%
# Final cumulative return of the strategy:  222.98%
# Final cumulative return of the strategy:  302.61%
# Final cumulative return of the strategy:  341.63%
# Final cumulative return of the strategy:  346.14%
# Final cumulative return of the strategy:  571.24%
# Final cumulative return of the strategy:  629.83%
# Final cumulative return of the strategy:  573.12%
# Final cumulative return of the strategy:  634.62%
# Final cumulative return of the strategy:  469.75%
# Final cumulative return of the strategy:  415.32%
# Final cumulative return of the strategy:  455.19%
# Final cumulative return of the strategy:  339.10%
# Final cumulative return of the strategy:  376.09%
# Final cumulative return of the strategy:  420.04%
# Final cumulative return of the strategy:  367.88%
# Final cumulative return of the strategy:  306.80%
# Final cumulative return of the strategy:  228.70%
# Final cumulative return of the strategy:  228.60%
# Final cumulative return of the strategy:  230.29%
# Final cumulative return of the strategy:  213.26%
# Final cumulative return of the strategy:  223.62%
# Final cumulative return of the strategy:  216.04%
# Final cumulative return of the strategy:  238.60%
# Final cumulative return of the strategy:  227.62%
# Final cumulative return of the strategy:  239.30%
# Final cumulative return of the strategy:  225.71%
# Final cumulative return of the strategy:  249.66%
# Final cumulative return of the strategy:  259.58%
# Final cumulative return of the strategy:  314.41%
# Final cumulative return of the strategy:  332.05%
# Final cumulative return of the strategy:  387.59%
# Final cumulative return of the strategy:  278.37%
# Final cumulative return of the strategy:  150.45%
# Final cumulative return of the strategy:  137.08%
# Final cumulative return of the strategy:  179.90%
# Final cumulative return of the strategy:  222.73%
# Final cumulative return of the strategy:  292.70%
# Final cumulative return of the strategy:  317.60%
# Final cumulative return of the strategy:  267.00%
# Final cumulative return of the strategy:  240.29%
# Final cumulative return of the strategy:  204.59%
# Final cumulative return of the strategy:  200.45%
# Final cumulative return of the strategy:  206.98%
# Final cumulative return of the strategy:  305.24%
# Final cumulative return of the strategy:  339.35%
# Final cumulative return of the strategy:  310.70%
# Final cumulative return of the strategy:  357.96%
# Final cumulative return of the strategy:  368.24%
# Final cumulative return of the strategy:  368.10%
# Final cumulative return of the strategy:  356.88%
# Final cumulative return of the strategy:  282.42%
# Final cumulative return of the strategy:  233.49%
# Final cumulative return of the strategy:  221.21%
# Final cumulative return of the strategy:  237.68%
# Final cumulative return of the strategy:  295.84%
# Final cumulative return of the strategy:  285.47%
# Final cumulative return of the strategy:  344.99%
# Final cumulative return of the strategy:  344.19%
# Final cumulative return of the strategy:  328.16%
# Final cumulative return of the strategy:  266.95%
# Final cumulative return of the strategy:  150.45%
# Final cumulative return of the strategy:  156.97%
# Final cumulative return of the strategy:  186.30%
# Final cumulative return of the strategy:  243.11%
# Final cumulative return of the strategy:  254.76%
# Final cumulative return of the strategy:  298.93%
# Final cumulative return of the strategy:  263.63%
# Final cumulative return of the strategy:  184.81%
# Final cumulative return of the strategy:  142.39%
# Final cumulative return of the strategy:  182.17%
# Final cumulative return of the strategy:  274.41%
# Final cumulative return of the strategy:  294.82%
# Final cumulative return of the strategy:  333.62%
# Final cumulative return of the strategy:  330.21%
# Final cumulative return of the strategy:  335.64%
# Final cumulative return of the strategy:  348.89%
# Final cumulative return of the strategy:  280.91%
# Final cumulative return of the strategy:  255.05%
# Final cumulative return of the strategy:  226.17%
# Final cumulative return of the strategy:  208.64%
# Final cumulative return of the strategy:  237.68%
# Final cumulative return of the strategy:  283.32%
# Final cumulative return of the strategy:  285.47%
# Final cumulative return of the strategy:  265.26%
# Final cumulative return of the strategy:  292.30%
# Max Tuples: [(5, 25, np.float64(16.738312676205794))]
# Optimal Parameters:(5, 25), Optimized Return: 1673.83%
# Final cumulative return of the strategy:  1673.83%
# Trading Period: 9.9 years
# Final cumulative return of the strategy: 1673.83%, Buy&Hold:934.18%
# Strategy CAGR:  33.69%, Benchmark CAGR: 26.60%
# Sharpe Ratio: 0.94
# Strategy MDD: -51.12%, Benchmark MDD: -81.66%
# Number of Profitable Trades:26, Number of Loss Trades:28, Win Rate:48.15%
# Average Holding Period:31.5days
# Avg ROR/trade in profitable trades:0.212%. Avg ROR/trade in loss trades:-0.060%
# Profit/Loss Ratio: 3.56

# %%
tear_sheet1(data)
# Out:
# Trading Period: 9.9 years
# Final cumulative return of the strategy: 2287.07%, Buy&Hold:934.18%
# Strategy CAGR:  37.76%, Benchmark CAGR: 26.60%
# Sharpe Ratio: 1.04
# Strategy MDD: -47.35%, Benchmark MDD: -81.66%
# Number of Profitable Trades:26, Number of Loss Trades:28, Win Rate:48.15%
# Average Holding Period:31.2days
# Avg ROR/trade in profitable trades:0.231%. Avg ROR/trade in loss trades:-0.060%
# Profit/Loss Ratio: 3.86

# %% [markdown]
# ## TQQQ 파라미터 최적화 및 추적손절 백테스트

# %%
import time

def parameter_optimizer3(input_df):
    #장단기 설정
    short_window = list(range(5, 22))  # 5~21
    long_window = list(range(22, 51))  # 22~50
    stop_loss = list(np.arange(0.05, 0.21, 0.01)) #range() 함수는 정수만 받음.
    ret_list=[] #각 파라미터 조합과 수익률을 저장할 리스트

    #장단기 및 스탑로스 모든 조합에 대해 테스트
    for x1, x2, x3 in [(a,b,c) for a in short_window for b in long_window for c in stop_loss]:
        df = input_df.copy()
        _, ret = mac_strategy2a(df, x1, x2, x3, verbose=False)
        ret_list.append((x1, x2, x3, ret))


    # 여러 개의 최적해를 '모두' 찾고 최적값은 중위값을 선택
    max_ror = max(ret_list, key=lambda x:x[3])[3]  # ret 값 기준으로 최대인 튜플 찾고, 거기서 ret값만 저장
    max_tups=[tup for tup in ret_list if tup[3] == max_ror] # 맥스 ret값을 만족하는 모든 tup 찾아서 리스트에 저장
    params1=[tup[0] for tup in max_tups] 
    params2=[tup[1] for tup in max_tups]
    params3=[tup[2] for tup in max_tups]
    opt_param1 = int(np.median(params1))
    opt_param2 = int(np.median(params2))
    opt_param3 = np.median(params3)
    
    optimal_df = pd.DataFrame(max_tups, columns=['short_window', 'long_window', 'stop_loss', 'ror'])  #리스트를 데이터프레임화. ror:파라미터 조합상 최종 수익률

    print(f'Max Tuples: {max_tups}')
    print(f'Optimal Parameters:{opt_param1}, {opt_param2}, {opt_param3:.2f}, ' f'Optimized Return:{100*max_ror: .2f}%')

    return (opt_param1, opt_param2, opt_param3), optimal_df # return optimal_params, optimal_df랑 동일

# %%
t1 = time.time() # 시작 시간 기록

optimal_params, optimal_df = parameter_optimizer3(df) # 최적화 감수 구동

t2 = time.time() # 끝난 시간 기록
    
print(f'Elapsed Time: {(t2-t1)/60:.2f}min')

data, ret = mac_strategy2a(df, optimal_params[0], optimal_params[1], optimal_params[2])
# Out:
# Max Tuples: [(5, 25, np.float64(0.15000000000000002), np.float64(22.870657726507424))]
# Optimal Parameters:5, 25, 0.15, Optimized Return: 2287.07%
# Elapsed Time: 1.15min
# Final cumulative return of the strategy:  2287.07%

# %%
tear_sheet1(data)
# Out:
# Trading Period: 9.9 years
# Final cumulative return of the strategy: 2287.07%, Buy&Hold:934.18%
# Strategy CAGR:  37.76%, Benchmark CAGR: 26.60%
# Sharpe Ratio: 1.04
# Strategy MDD: -47.35%, Benchmark MDD: -81.66%
# Number of Profitable Trades:26, Number of Loss Trades:28, Win Rate:48.15%
# Average Holding Period:31.2days
# Avg ROR/trade in profitable trades:0.231%. Avg ROR/trade in loss trades:-0.060%
# Profit/Loss Ratio: 3.86
